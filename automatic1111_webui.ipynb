# %%
# %cd /content/
# !git clone https://github.com/lllyasviel/stable-diffusion-webui-forge.git
# !pip install pydantic
# !wget https://huggingface.co/SG161222/RealVisXL_V5.0_Lightning/resolve/main/RealVisXL_V5.0_Lightning_fp16.safetensors -P /content/stable-diffusion-webui-forge/models/Stable-diffusion
# !wget https://huggingface.co/RunDiffusion/Juggernaut-XL-v9/resolve/main/Juggernaut-XL_v9_RunDiffusionPhoto_v2.safetensors -P /content/stable-diffusion-webui-forge/models/Stable-diffusion
# !wget https://huggingface.co/segmind/SSD-1B/resolve/main/SSD-1B-A1111.safetensors -P /content/stable-diffusion-webui-forge/models/Stable-diffusion
#!wget url -P /content/stable-diffusion-webui-forge/models/Stable-diffusion
#!wget url -P /content/stable-diffusion-webui-forge/models/Stable-diffusion
# !python /content/stable-diffusion-webui-forge/launch.py --share
# Out:
# /content
# Cloning into 'stable-diffusion-webui-forge'...
# remote: Enumerating objects: 41781, done.
# remote: Counting objects: 100% (10635/10635), done.
# remote: Compressing objects: 100% (759/759), done.
# remote: Total 41781 (delta 10041), reused 9876 (delta 9876), pack-reused 31146 (from 3)
# Receiving objects: 100% (41781/41781), 46.14 MiB | 14.37 MiB/s, done.
# Resolving deltas: 100% (29093/29093), done.
# ...
# --2024-12-22 23:41:24--  https://huggingface.co/stable-diffusion-v1-5/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.safetensors
# Resolving huggingface.co (huggingface.co)... 3.165.102.58, 3.165.102.22, 3.165.102.6, ...
# Connecting to huggingface.co (huggingface.co)|3.165.102.58|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...
